# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab
import glob
import datetime

# %%
dataDir =r"C:/Ramya Dhatri/Intro To Data Science/Project/Data/bikeshare_nyc_raw.csv"
data = pd.read_csv(dataDir, sep='\t')
data

# %%
data[]
# Out:
#          dock_id                dock_name      date  hour  minute  pm  \
# 0             72         W 52 St & 11 Ave  16-06-01     7      25   1
# 1             72         W 52 St & 11 Ave  16-06-01     7      34   1
# 2             72         W 52 St & 11 Ave  16-06-01     7      51   1
# 3             72         W 52 St & 11 Ave  16-06-01     8       9   1
# 4             72         W 52 St & 11 Ave  16-06-01     8      26   1
# 5             72         W 52 St & 11 Ave  16-06-01     8      43   1
# 6             72         W 52 St & 11 Ave  16-06-01     9       0   1
# 7             72         W 52 St & 11 Ave  16-06-01     9      17   1
# 8             72         W 52 St & 11 Ave  16-06-01     9      33   1
# 9             72         W 52 St & 11 Ave  16-06-01     9      53   1
# 10            72         W 52 St & 11 Ave  16-06-01    10      11   1
# 11            72         W 52 St & 11 Ave  16-06-01    10      27   1
# ...

# %%
data_morning = data[(data['pm'] == 0) & (data['hour'].isin(range(6,11)))]
data_evening = data[(data['pm'] == 1) & (data['hour'].isin(range(4,9)))]
data_rush = pd.concat([data_morning, data_evening])
data_rush

# %%
for row in data_rush.iterrows():
    print row['date']
    break
    #date = row['date'].split("-")
    #year = int("20"+date[0])
    #month = int(date[1])
    #day = int(date[2])
    #datetime.datetime(year, month, day)
    #data['Day'] = datetime.datetime.today().weekday()
#data_rush

# %%
str = "16-06-12"
date = str.split("-")
date
year = int("20"+date[0])
month = int(date[1])
day = int(date[2])
datetime.datetime(year, month, day)
datetime.datetime.today().weekday()
# Out:
# 4
