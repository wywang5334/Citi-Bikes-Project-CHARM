# %%
import os, sys
import pandas as pd
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
import datetime
from datetime import date
# %matplotlib inline

# %%
data_dir = '/Users/honggao/Downloads/2016-06/'
data_filedir = data_dir + 'bikeshare_nyc_raw.csv'

# %%
data = pd.read_table(data_filedir, sep='\t')
data.head()
# Out:
#    dock_id         dock_name      date  hour  minute  pm  avail_bikes  \
# 0       72  W 52 St & 11 Ave  16-06-01     7      25   1           10
# 1       72  W 52 St & 11 Ave  16-06-01     7      34   1           11
# 2       72  W 52 St & 11 Ave  16-06-01     7      51   1           12
# 3       72  W 52 St & 11 Ave  16-06-01     8       9   1           12
# 4       72  W 52 St & 11 Ave  16-06-01     8      26   1           17
#
#    avail_docks  tot_docks       _lat      _long  in_service  status_key
# 0           28         39  40.767272 -73.993929           1           1
# 1           27         39  40.767272 -73.993929           1           1
# 2           26         39  40.767272 -73.993929           1           1
# 3           26         39  40.767272 -73.993929           1           1
# 4           21         39  40.767272 -73.993929           1           1

# %%
data.describe()
# Out:
#             dock_id          hour        minute            pm   avail_bikes  \
# count  1.078789e+06  1.078789e+06  1.078789e+06  1.078789e+06  1.078789e+06
# mean   1.462416e+03  6.432295e+00  2.954338e+01  4.783836e-01  1.137565e+01
# std    1.339699e+03  3.455563e+00  1.735355e+01  4.995327e-01  1.100695e+01
# min    7.200000e+01  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.480000e+02  3.000000e+00  1.400000e+01  0.000000e+00  2.000000e+00
# 50%    4.900000e+02  6.000000e+00  3.000000e+01  0.000000e+00  8.000000e+00
# 75%    3.107000e+03  9.000000e+00  4.500000e+01  1.000000e+00  1.800000e+01
# max    3.260000e+03  1.200000e+01  5.900000e+01  1.000000e+00  6.400000e+01
#
#         avail_docks     tot_docks          _lat         _long    in_service  \
# count  1.078789e+06  1.078789e+06  1.078789e+06  1.078789e+06  1.078789e+06
# mean   2.032476e+01  3.273813e+01  4.070052e+01 -7.393365e+01  9.835631e-01
# std    1.402042e+01  1.136863e+01  1.059447e+00  1.924108e+00  1.271487e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00 -7.409694e+01  0.000000e+00
# 25%    9.000000e+00  2.400000e+01  4.070853e+01 -7.399705e+01  1.000000e+00
# 50%    1.800000e+01  3.100000e+01  4.072503e+01 -7.398267e+01  1.000000e+00
# 75%    3.000000e+01  3.900000e+01  4.074890e+01 -7.396264e+01  1.000000e+00
# max    6.700000e+01  6.700000e+01  4.078721e+01  0.000000e+00  1.000000e+00
#
#          status_key
# count  1.078789e+06
# mean   1.030308e+00
# std    2.443309e-01
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    1.000000e+00
# 75%    1.000000e+00
# max    3.000000e+00

# %%
data.shape
# Out:
# (1078789, 13)

# %%
data.dtypes
# Out:
# dock_id          int64
# dock_name       object
# date            object
# hour             int64
# minute           int64
# pm               int64
# avail_bikes      int64
# avail_docks      int64
# tot_docks        int64
# _lat           float64
# _long          float64
# in_service       int64
# status_key       int64
# dtype: object

# %%
# keep rush hours 6-10am and 4-8pm
data_morning = data[(data['pm'] == 0) & (data['hour'].isin(range(6,11)))]
data_morning.head()
# Out:
#     dock_id         dock_name      date  hour  minute  pm  avail_bikes  \
# 36       72  W 52 St & 11 Ave  16-06-02     6       6   0           20
# 37       72  W 52 St & 11 Ave  16-06-02     6      22   0           19
# 38       72  W 52 St & 11 Ave  16-06-02     6      39   0           22
# 39       72  W 52 St & 11 Ave  16-06-02     6      56   0           23
# 40       72  W 52 St & 11 Ave  16-06-02     7      14   0           23
#
#     avail_docks  tot_docks       _lat      _long  in_service  status_key
# 36           18         39  40.767272 -73.993929           1           1
# 37           19         39  40.767272 -73.993929           1           1
# 38           16         39  40.767272 -73.993929           1           1
# 39           15         39  40.767272 -73.993929           1           1
# 40           15         39  40.767272 -73.993929           1           1

# %%
data_afternoon = data[(data['pm'] == 1) & (data['hour'].isin(range(4,9)))]
data_afternoon.head()
# Out:
#    dock_id         dock_name      date  hour  minute  pm  avail_bikes  \
# 0       72  W 52 St & 11 Ave  16-06-01     7      25   1           10
# 1       72  W 52 St & 11 Ave  16-06-01     7      34   1           11
# 2       72  W 52 St & 11 Ave  16-06-01     7      51   1           12
# 3       72  W 52 St & 11 Ave  16-06-01     8       9   1           12
# 4       72  W 52 St & 11 Ave  16-06-01     8      26   1           17
#
#    avail_docks  tot_docks       _lat      _long  in_service  status_key
# 0           28         39  40.767272 -73.993929           1           1
# 1           27         39  40.767272 -73.993929           1           1
# 2           26         39  40.767272 -73.993929           1           1
# 3           26         39  40.767272 -73.993929           1           1
# 4           21         39  40.767272 -73.993929           1           1

# %%
data = pd.concat([data_morning, data_afternoon])

# %%
data['shortage'] = [1 if x<=5 else 0 for x in data['avail_bikes']]

# %%
data.head()
# Out:
#     dock_id         dock_name      date  hour  minute  pm  avail_bikes  \
# 36       72  W 52 St & 11 Ave  16-06-02     6       6   0           20
# 37       72  W 52 St & 11 Ave  16-06-02     6      22   0           19
# 38       72  W 52 St & 11 Ave  16-06-02     6      39   0           22
# 39       72  W 52 St & 11 Ave  16-06-02     6      56   0           23
# 40       72  W 52 St & 11 Ave  16-06-02     7      14   0           23
#
#     avail_docks  tot_docks       _lat      _long  in_service  status_key  \
# 36           18         39  40.767272 -73.993929           1           1
# 37           19         39  40.767272 -73.993929           1           1
# 38           16         39  40.767272 -73.993929           1           1
# 39           15         39  40.767272 -73.993929           1           1
# 40           15         39  40.767272 -73.993929           1           1
#
#     shortage
# 36         0
# 37         0
# 38         0
# 39         0
# 40         0

# %%
data['datetime'] = pd.to_datetime(data['date'], format='%y-%m-%d')
data.head()
# Out:
#     dock_id         dock_name      date  hour  minute  pm  avail_bikes  \
# 36       72  W 52 St & 11 Ave  16-06-02     6       6   0           20
# 37       72  W 52 St & 11 Ave  16-06-02     6      22   0           19
# 38       72  W 52 St & 11 Ave  16-06-02     6      39   0           22
# 39       72  W 52 St & 11 Ave  16-06-02     6      56   0           23
# 40       72  W 52 St & 11 Ave  16-06-02     7      14   0           23
#
#     avail_docks  tot_docks       _lat      _long  in_service  status_key  \
# 36           18         39  40.767272 -73.993929           1           1
# 37           19         39  40.767272 -73.993929           1           1
# 38           16         39  40.767272 -73.993929           1           1
# 39           15         39  40.767272 -73.993929           1           1
# 40           15         39  40.767272 -73.993929           1           1
#
#     shortage   datetime
# 36         0 2016-06-02
# 37         0 2016-06-02
# 38         0 2016-06-02
# 39         0 2016-06-02
# 40         0 2016-06-02

# %%
data.dtypes
# Out:
# dock_id                 int64
# dock_name              object
# date                   object
# hour                    int64
# minute                  int64
# pm                      int64
# avail_bikes             int64
# avail_docks             int64
# tot_docks               int64
# _lat                  float64
# _long                 float64
# in_service              int64
# status_key              int64
# shortage                int64
# datetime       datetime64[ns]
# dtype: object

# %%
data['day_of_week'] = data['datetime'].dt.weekday_name
data.head()
# Out:
#     dock_id         dock_name      date  hour  minute  pm  avail_bikes  \
# 36       72  W 52 St & 11 Ave  16-06-02     6       6   0           20
# 37       72  W 52 St & 11 Ave  16-06-02     6      22   0           19
# 38       72  W 52 St & 11 Ave  16-06-02     6      39   0           22
# 39       72  W 52 St & 11 Ave  16-06-02     6      56   0           23
# 40       72  W 52 St & 11 Ave  16-06-02     7      14   0           23
#
#     avail_docks  tot_docks       _lat      _long  in_service  status_key  \
# 36           18         39  40.767272 -73.993929           1           1
# 37           19         39  40.767272 -73.993929           1           1
# 38           16         39  40.767272 -73.993929           1           1
# 39           15         39  40.767272 -73.993929           1           1
# 40           15         39  40.767272 -73.993929           1           1
#
#     shortage   datetime day_of_week
# 36         0 2016-06-02    Thursday
# 37         0 2016-06-02    Thursday
# 38         0 2016-06-02    Thursday
# 39         0 2016-06-02    Thursday
# 40         0 2016-06-02    Thursday

# %%
# days = {'weekday':['Monday', 'Tuesday', 'Wednesday', 'Thursday'],'weekend':['Friday', 'Saturday', 'Sunday']}

data['weekday'] = [0 if x in ['Saturday','Sunday'] else 1 for x in data['day_of_week']]

# %%
data.head()
# Out:
#     dock_id         dock_name      date  hour  minute  pm  avail_bikes  \
# 36       72  W 52 St & 11 Ave  16-06-02     6       6   0           20
# 37       72  W 52 St & 11 Ave  16-06-02     6      22   0           19
# 38       72  W 52 St & 11 Ave  16-06-02     6      39   0           22
# 39       72  W 52 St & 11 Ave  16-06-02     6      56   0           23
# 40       72  W 52 St & 11 Ave  16-06-02     7      14   0           23
#
#     avail_docks  tot_docks       _lat      _long  in_service  status_key  \
# 36           18         39  40.767272 -73.993929           1           1
# 37           19         39  40.767272 -73.993929           1           1
# 38           16         39  40.767272 -73.993929           1           1
# 39           15         39  40.767272 -73.993929           1           1
# 40           15         39  40.767272 -73.993929           1           1
#
#     shortage   datetime day_of_week  weekday
# 36         0 2016-06-02    Thursday        1
# 37         0 2016-06-02    Thursday        1
# 38         0 2016-06-02    Thursday        1
# 39         0 2016-06-02    Thursday        1
# 40         0 2016-06-02    Thursday        1
